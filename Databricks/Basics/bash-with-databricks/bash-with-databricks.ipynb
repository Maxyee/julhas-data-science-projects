# %%
touch work.txt
# Out:
#   File "<command-944822195028975>", line 1
#     touch work.txt
#           ^
# SyntaxError: invalid syntax

# %%
# %sh
# Out:
# %sh: run a Unix shell command.
# Use %sh -e to fail command execution in case of non-zero exit code.

# %%
# %sh
touch work.txt

# %%
ls
# Out:
# conf/  eventlogs/  ganglia/  logs/  metastore_db/  preload_class.lst*  work.txt

# %%
rm work.txt

# %%
ls
# Out:
# conf/  eventlogs/  ganglia/  logs/  metastore_db/  preload_class.lst*

# %%
wget https :// www.secrepo.com / auth . log / auth . log . gz
# Out:
#   File "<command-944822195028981>", line 1
#     wget https :// www.secrepo.com / auth . log / auth . log . gz
#          ^
# SyntaxError: invalid syntax

# %%
wget https://www.secrepo.com/auth.log/auth.log.gz
# Out:
#   File "<command-944822195028982>", line 1
#     wget https://www.secrepo.com/auth.log/auth.log.gz
#          ^
# SyntaxError: invalid syntax

# %%
# %sh
wget https://www.secrepo.com/auth.log/auth.log.gz
# Out:
# --2022-02-02 14:25:06--  https://www.secrepo.com/auth.log/auth.log.gz
# Resolving www.secrepo.com (www.secrepo.com)... 66.33.221.139
# Connecting to www.secrepo.com (www.secrepo.com)|66.33.221.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 615271 (601K) [application/gzip]
# Saving to: ‘auth.log.gz’
#
#      0K .......... .......... .......... .......... ..........  8%  321K 2s
#     50K .......... .......... .......... .......... .......... 16%  643K 1s
#    100K .......... .......... .......... .......... .......... 24% 26.7M 1s
#    150K .......... .......... .......... .......... .......... 33%  661K 1s
#    200K .......... .......... .......... .......... .......... 41% 15.6M 0s
#    250K .......... .......... .......... .......... .......... 49%  117M 0s
#    300K .......... .......... .......... .......... .......... 58% 88.6M 0s
#    350K .......... .......... .......... .......... .......... 66% 52.3M 0s
# ...

# %%
gunzip auth.log.gz
# Out:
#   File "<command-944822195028984>", line 1
#     gunzip auth.log.gz
#            ^
# SyntaxError: invalid syntax

# %%
# %sh
gunzip auth.log.gz

# %%
ls
# Out:
# auth.log  conf/  eventlogs/  ganglia/  logs/  metastore_db/  preload_class.lst*

# %%
cp auth.log temporary_logs.txt

# %%
ls
# Out:
# auth.log  eventlogs/  logs/          preload_class.lst*
# conf/     ganglia/    metastore_db/  temporary_logs.txt

# %%
head -n 4 temporary_logs.txt
# Out:
#   File "<command-944822195028989>", line 1
#     head -n 4 temporary_logs.txt
#             ^
# SyntaxError: invalid syntax

# %%
$>head -n 4 temporary_logs.txt
# Out:
#   File "<command-944822195028990>", line 1
#     $>head -n 4 temporary_logs.txt
#     ^
# SyntaxError: invalid syntax

# %%
# %sh
$>head -n 4 temporary_logs.txt
# Out:
# /bin/bash: $: command not found

# %%
# %sh
head -n 4 temporary_logs.txt
# Out:
# Nov 30 06:39:00 ip-172-31-27-153 CRON[21882]: pam_unix(cron:session): session closed for user root
# Nov 30 06:47:01 ip-172-31-27-153 CRON[22087]: pam_unix(cron:session): session opened for user root by (uid=0)
# Nov 30 06:47:03 ip-172-31-27-153 CRON[22087]: pam_unix(cron:session): session closed for user root
# Nov 30 07:07:14 ip-172-31-27-153 sshd[22116]: Connection closed by 122.225.103.87 [preauth]

# %%
# %sh
head -n 10 temporary_logs.txt
# Out:
# Nov 30 06:39:00 ip-172-31-27-153 CRON[21882]: pam_unix(cron:session): session closed for user root
# Nov 30 06:47:01 ip-172-31-27-153 CRON[22087]: pam_unix(cron:session): session opened for user root by (uid=0)
# Nov 30 06:47:03 ip-172-31-27-153 CRON[22087]: pam_unix(cron:session): session closed for user root
# Nov 30 07:07:14 ip-172-31-27-153 sshd[22116]: Connection closed by 122.225.103.87 [preauth]
# Nov 30 07:07:35 ip-172-31-27-153 sshd[22118]: Connection closed by 122.225.103.87 [preauth]
# Nov 30 07:08:13 ip-172-31-27-153 sshd[22120]: Connection closed by 122.225.103.87 [preauth]
# Nov 30 07:17:01 ip-172-31-27-153 CRON[22125]: pam_unix(cron:session): session opened for user root by (uid=0)
# Nov 30 07:17:01 ip-172-31-27-153 CRON[22125]: pam_unix(cron:session): session closed for user root
# Nov 30 08:17:01 ip-172-31-27-153 CRON[22172]: pam_unix(cron:session): session opened for user root by (uid=0)
# ...

# %%
# %sh
head -n 17 temporary_logs.txt
# Out:
# Nov 30 06:39:00 ip-172-31-27-153 CRON[21882]: pam_unix(cron:session): session closed for user root
# Nov 30 06:47:01 ip-172-31-27-153 CRON[22087]: pam_unix(cron:session): session opened for user root by (uid=0)
# Nov 30 06:47:03 ip-172-31-27-153 CRON[22087]: pam_unix(cron:session): session closed for user root
# Nov 30 07:07:14 ip-172-31-27-153 sshd[22116]: Connection closed by 122.225.103.87 [preauth]
# Nov 30 07:07:35 ip-172-31-27-153 sshd[22118]: Connection closed by 122.225.103.87 [preauth]
# Nov 30 07:08:13 ip-172-31-27-153 sshd[22120]: Connection closed by 122.225.103.87 [preauth]
# Nov 30 07:17:01 ip-172-31-27-153 CRON[22125]: pam_unix(cron:session): session opened for user root by (uid=0)
# Nov 30 07:17:01 ip-172-31-27-153 CRON[22125]: pam_unix(cron:session): session closed for user root
# Nov 30 08:17:01 ip-172-31-27-153 CRON[22172]: pam_unix(cron:session): session opened for user root by (uid=0)
# ...

# %%
# %sh
wc -l temporary_logs.txt
# Out:
# 86839 temporary_logs.txt

# %%
# %sh
grep 'invalid user' temporary_logs.txt
# Out:
# Nov 30 08:42:04 ip-172-31-27-153 sshd[22182]: input_userauth_request: invalid user admin [preauth]
# Nov 30 10:58:27 ip-172-31-27-153 sshd[22291]: input_userauth_request: invalid user admin [preauth]
# Nov 30 15:22:39 ip-172-31-27-153 sshd[22844]: input_userauth_request: invalid user admin [preauth]
# Nov 30 15:22:43 ip-172-31-27-153 sshd[22847]: input_userauth_request: invalid user guest [preauth]
# Nov 30 15:22:48 ip-172-31-27-153 sshd[22849]: input_userauth_request: invalid user support [preauth]
# Nov 30 17:47:52 ip-172-31-27-153 sshd[22960]: input_userauth_request: invalid user avconroot [preauth]
# Nov 30 17:47:55 ip-172-31-27-153 sshd[22962]: input_userauth_request: invalid user avconroot [preauth]
# Nov 30 17:47:58 ip-172-31-27-153 sshd[22964]: input_userauth_request: invalid user avconroot [preauth]
# Nov 30 17:48:00 ip-172-31-27-153 sshd[22966]: input_userauth_request: invalid user webmaster [preauth]
# ...

# %%
# %sh
grep -c 'invalid user' temporary_logs.txt
# Out:
# 12250

# %%
# %sh
gzip temporary_logs.txt

# %%
ls
# Out:
# auth.log  eventlogs/  head   metastore_db/       temporary_logs.txt.gz
# conf/     ganglia/    logs/  preload_class.lst*
